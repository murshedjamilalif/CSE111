# %%
#Task 01
class Marks:
    def __init__(self,x):
        self.mark=x
    def __add__(self,other):
        self.mark+=other.mark
        Total=Marks(self.mark)
        return Total
Q1 = Marks(int(input("Quiz 1 (out of 10): ")))
Q2 = Marks(int(input("Quiz 2 (out of 10): ")))
Lab = Marks(int(input("Lab (out of 30): ")))
Mid = Marks(int(input("Mid (out of 20): ")))
Final = Marks(int(input("Final (out of 30): ")))
total = Q1 + Q2 + Lab + Mid + Final
print("Total marks: {}".format(total.mark))

# %%
#Task 2
class Course:
    def __init__(self,course):
        #print(type(course))
        self.course=course
class Teacher:
    def __init__(self,name,dept):
        self.__name=name
        self.__course_list=[]
        self.__dep=dept
    def addCourse(self,*taken_courses):
        #print(type(taken_courses))###########"""tuple"""#############
        for i in taken_courses:
            #print("i.course=",i.course)###################
            self.__course_list+=[i.course]
    def printDetail(self):
        print('====================================')
        print('Name:',self.__name)
        print('Department:',self.__dep)
        print('List of courses')
        print('====================================')
        for i in self.__course_list:
            print(i)
        print('====================================')
t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")
c1 = Course("CSE 110 Programming Language I")
c2 = Course("CSE 111 Programming Language-II")
c3 = Course("CSE 220 Data Structures")
c4 = Course("CSE 221 Algorithms")
c5 = Course("CCSE 230 Discrete Mathematics")
c6 = Course("CSE 310 Object Oriented Programming")
c7 = Course("CSE 320 Data Communications")
c8 = Course("CSE 340 Computer Architecture")
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()

# %%
#task 3
class Team:
    def __init__(self,team=None):
        self.__team=team
        self.__player=[]
    def setName(self,country):
        self.__team=country
    def addPlayer(self,*player):
        for i in player:
            self.__player.append(i.player)
        return self.__player
    def printDetail(self):
        print("=========================")
        print("Team",self.__team)
        print("List of Players:")
        print(self.__player)
        print("=========================")
class Player:
    def __init__(self,player):
        self.player=player
b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()

# %%
#Task 04
class Color:
        def __init__(self,color):
            self.clr=color
           
        def __add__(self,other):
            colors=self.clr+other.clr
            if 'red' in colors and 'yellow' in colors:
                return Color('Orange')
            elif  'red' in colors and 'blue' in colors:
                return Color('Violet')
            else:
                return Color('Green')
C1 = Color(input("First Color: ").lower())
C2 = Color(input("Second Color: ").lower())
C3 = C1 + C2
print("Color formed:", C3.clr)

# %%
#Task 05
import math
class Circle:
    def __init__(self,radius):
        self.__radius=radius
        #################print('self.__radius',self.__radius)#################
    def setRadius(self,rad):
        self.__radius=rad
        
    def getRadius(self):
        return self.__radius
    def __add__(self,other):
        self.__radius+=other.__radius
        print(self.__radius)
        r= self.__radius
        return  Circle(r)
    def area(self):
       
        self.__area=math.pi.__mul__(self.__radius.__pow__(2))
        return self.__area
c1 = Circle(4)
print("First circle radius:" , c1.getRadius()) 
print("First circle area:" ,c1.area()) 
c2 = Circle(5) 
print("Second circle radius:" ,c2.getRadius()) 
print("Second circle area:" ,c2.area()) 
c3 = c1 + c2 
print("Third circle radius:" ,c3.getRadius()) 
print("Third circle area:" ,c3.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483
# 9
# Third circle radius: 9
# Third circle area: 254.46900494077323

# %%
#Task 06
class Triangle:
    def __init__(self, base, height):
        self.__hei=height
        self.__ba=base
    def setHeight(self,height):
        self.__hei=height
    def setBase(self,base):
        self.__ba=base
    def __sub__(self,other):
        self.__base=self.__ba-other.__ba
        self.__height=self.__hei-other.__hei
        return Triangle(self.__base,self.__height)
    def getHeight(self):
        return self.__hei
    def getBase(self):
        return self.__ba
    def area(self):
        self.__area=0.5.__mul__(self.__ba).__mul__(self.__hei)
        return self.__area
    
t1 = Triangle(10, 5) 
print("First Triangle Base:", t1.getBase()) 
print("First Triangle Height:" , t1.getHeight()) 
print("First Triangle area:" ,t1.area()) 
t2 = Triangle(5, 3) 
print("Second Triangle Base:" , t2.getBase()) 
print("Second Triangle Height:" , t2.getHeight()) 
print("Second Triangle area:" ,t2.area()) 
t3 = t1 - t2  
print("Third Triangle Base:" , t3.getBase()) 
print("Third Triangle Height:" , t3.getHeight()) 
print("Third Triangle area:" ,t3.area())

# %%
#task 7
class Dolls:
    def __init__(self,doll,price):
        self.doll=doll
        self.price=price
    
    def __gt__(self,other):
        if self.price>other.price:
            return True
        else:
            return False
    def __add__(self,other):
        price=self.price+other.price
        dolls=self.doll+other.doll
        return Dolls(dolls,price)
    def detail(self):
        print("Dolls:",self.doll)
        print("Total Price:",self.price,end='')
        return "taka"
        
        




obj_1 = Dolls("Tweety", 2500)
print(obj_1.detail())
if obj_1 > obj_1:
 print("Congratulations! You get the Tweety as a gift!")
else:
 print("Thank you!")
print("=========================")
obj_2 = Dolls("Daffy Duck", 1800)
print(obj_2.detail())
if obj_2 > obj_1:
 print("Congratulations! You get the Tweety as a gift!")
else:
 print("Thank you!")
print("=========================")
obj_3 = Dolls("Bugs Bunny", 3000)
print(obj_3.detail())
if obj_3 > obj_1:
 print("Congratulations! You get the Tweety as a gift!")
else:
 print("Thank you!")
print("=========================")
obj_4 = Dolls("Porky Pig", 1500)
print(obj_4.detail())
if obj_4 > obj_1:
 print("Congratulations! You get the Tweety as a gift!")
else:
 print("Thank you!")
print("=========================")
obj_5 = obj_2 + obj_3
print(obj_5.detail())
if obj_5 > obj_1:
 print("Congratulations! You get the Tweety as a gift!")
else:
 print("Thank you!")
# Out:
# Dolls: Tweety
# Total Price: 2500taka
# Thank you!
# ...
# Dolls: Daffy Duck
# Total Price: 1800taka
# Thank you!
# ...
# Dolls: Bugs Bunny
# Total Price: 3000taka
# Congratulations! You get the Tweety as a gift!
# ...
# Dolls: Porky Pig
# Total Price: 1500taka
# Thank you!
# ...
# Dolls: Daffy DuckBugs Bunny
# Total Price: 4800taka
# Congratulations! You get the Tweety as a gift!

# %%
#task 08
class Coordinates:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __sub__(self,other):
        a=self.x-other.x
        b=self.y-other.y
        return Coordinates(a,b)
    def __mul__(self,other):
        a=self.x * other.x
        b=self.y * other.y
        return Coordinates(a,b)
    def __eq__(self,other):
        if (self.x==other.x) and (self.y==other.y):
            return 'The calculated coordinates are the same.'
        else:
            return 'The calculated coordinates are NOT the same.'
    def detail(self):
         return '({},{})'.format(self.x,self.y)
        
p1 = Coordinates(int(input()),int(input()))
p2 = Coordinates(int(input()),int(input()))
p4 = p1 - p2
print(p4.detail())
p5 = p1 * p2
print(p5.detail())
point_check = (p4 == p5)
print(point_check)
# Out:
# 1
# 2
# 3
# 4
# (-2,-2)
# (3,8)
# The calculated coordinates are NOT the same.
