# %%
#Task 1
class Student:
  ID=0
  def __init__(self,name,department,age,cgpa):
    self.__name=name
    self.__dept=department
    self.__age=age
    self.__cg=cgpa
    Student.ID+=1
    self.__ID=Student.ID
  def get_details(self):    
    print('ID:',self.__ID)
    print('Name:',self.__name)
    print('Department: ',self.__dept)
    print('Age: ',self.__age)
    print('CGPA: ',self.__cg)
  @classmethod
  def from_String(cls,details):
    name,department,age,cgpa=details.split('-')
    Info=cls(name,department,age,cgpa)
    return Info
s1 = Student("Samin", "CSE", 21, 3.91)
s1.get_details()
print("-----------------------")
s2 = Student("Fahim", "ECE", 21, 3.85)
s2.get_details()
print("-----------------------")
s3 = Student("Tahura", "EEE", 22, 3.01)
s3.get_details()
print("-----------------------")
s4 = Student.from_String("Sumaiya-BBA-23-3.96")
s4.get_details()
print('\nAnswer to 5th Subtask:','\nA class variable is shared through every instance of that class whereas an instance variable is unique for every different object.')
print('\nAnswer to 6th Subtask:','\nAn instance method is bound to both class and object whereas a class variable is only bound to the class and not any objects.')
# Out:
# ID: 1
# Name: Samin
# Department:  CSE
# Age:  21
# CGPA:  3.91
# -----------------------
# ID: 2
# Name: Fahim
# Department:  ECE
# Age:  21
# CGPA:  3.85
# -----------------------
# ID: 3
# Name: Tahura
# Department:  EEE
# Age:  22
# CGPA:  3.01
# -----------------------
# ID: 4
# Name: Sumaiya
# Department:  BBA
# Age:  23
# CGPA:  3.96
#
# Answer to 5th Subtask:
# A class variable is shared through every instance of that class whereas an instance variable is unique for every different object.
#
# Answer to 6th Subtask:
# An instance method is bound to both class and object whereas a class variable is only bound to the class and not any objects.

# %%
#Task 2
class Assassin:
  Number=0
  def __init__(self,name,success):
    self.name=name
    self.success=success
    Assassin.Number+=1
    self.number=Assassin.Number
  @classmethod
  def failurePercentage(cls,name,success):
    obj=cls(name,100-success)
    return obj
  @classmethod
  def failureRate(cls,name,success):
    obj1=cls(name,100-success)
    return obj1
  def printDetails(self):
    print('Name: ',self.name)
    print('Success Rate: ',str(self.success)+'%')
    print('Total number of Assassin: ',self.number)
john_wick = Assassin('John Wick', 100)
john_wick.printDetails()
print('================================')
nagisa = Assassin.failureRate("Nagisa", 20)
nagisa.printDetails()
print('================================')
akabane = Assassin.failurePercentage('Akabane', 10)
akabane.printDetails()
# Out:
# Name:  John Wick
# Success Rate:  100%
# Total number of Assassin:  1
# ...
# Name:  Nagisa
# Success Rate:  80%
# Total number of Assassin:  2
# ...
# Name:  Akabane
# Success Rate:  90%
# Total number of Assassin:  3

# %%
#Task 3
class Passenger:
  count=0
  def __init__(self,name):
    self.name=name
    Passenger.count+=1
    self.total=Passenger.count
    self.charge=450
  def set_bag_weight(self,weight):
    self.wt=weight
    if weight<=20:
      self.charge+=0
    elif 21<=weight<=50:
      self.charge+=50
    else:
      self.charge+=100
  def printDetail(self):
    print('Name:',self.name)
    print('Bus Fare:',self.charge,'taka')
print('Total Passenger:', Passenger.count) 
p1 = Passenger('Jack') 
p1.set_bag_weight(90) 
p2 = Passenger('Carol') 
p2.set_bag_weight(10) 
p3 = Passenger('Mike') 
p3.set_bag_weight(25) 
print("=========================") 
p1.printDetail() 
print("=========================") 
p2.printDetail() 
print("=========================") 
p3.printDetail() 
print("=========================") 
print('Total Passenger:', Passenger.count)
# Out:
# Total Passenger: 0
# ...
# Name: Jack
# Bus Fare: 550 taka
# ...
# Name: Carol
# Bus Fare: 450 taka
# ...
# Name: Mike
# Bus Fare: 500 taka
# ...
# Total Passenger: 3

# %%
#Task 4
class Travel:
  count=0
  def __init__(self,start,end):
    self.start=start
    self.end=end
    Travel.count+=1
    self.count=Travel.count
    self.time=1
  def set_time(self,time):
    self.time=time
  def set_destination(self,place):
    self.end=place
  def set_source(self,place2):
    self.start=place2
  def display_travel_info(self):
    return f"Source: {self.start}\nDestination: {self.end}\nFlight Time: {str(self.time)+':00'}"
print('No. of Traveller =', Travel.count)
print("=======================")
t1 = Travel("Dhaka","India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur","Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka","New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka","India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================") 
print('No. of Traveller =', Travel.count)
# Out:
# No. of Traveller = 0
# ...
# Source: Dhaka
# Destination: India
# Flight Time: 1:00
# ...
# Source: Kuala Lampur
# Destination: Dhaka
# Flight Time: 23:00
# ...
# Source: Dhaka
# Destination: Germany
# Flight Time: 15:00
# ...
# Source: Malaysia
# Destination: Canada
# Flight Time: 9:00
# ...
# No. of Traveller = 4

# %%
#Task 5
class Employee:
  def __init__(self,name,workingPeriod):
    self.name=name
    self.workingPeriod=workingPeriod
  @classmethod
  def employeeByJoiningYear(cls,name,year):
    workingPeriod=2021-year
    obj=cls(name,workingPeriod)
    return obj
  @staticmethod
  def experienceCheck(workingPeriod,gender):
    if workingPeriod<3 and gender=='male':
      return 'He is not experienced'
    elif workingPeriod<3 and gender=='female':
      return 'She is not experienced'
    elif workingPeriod>3 and gender=='male':
      return 'He is experienced'
    else:
      return 'She is experienced'
employee1 = Employee('Dororo', 3)
employee2 = Employee.employeeByJoiningYear('Harry', 2016)
print(employee1.workingPeriod)
print(employee2.workingPeriod)
print(employee1.name)
print(employee2.name) 
print(Employee.experienceCheck(2, "male")) 
print(Employee.experienceCheck(3, "female"))
# Out:
# 3
# 5
# Dororo
# Harry
# He is not experienced
# She is experienced

# %%
#Task 6
class Laptop:
  laptopCount=0
  def __init__(self,name,count):
    self.name=name
    self.count=count
    Laptop.laptopCount+=self.count
  @classmethod
  def advantage(cls):
    print('Laptops are portable')
  @classmethod
  def resetCount(cls):
    Laptop.laptopCount=0
    return Laptop.laptopCount
lenovo = Laptop("Lenovo", 5);
dell = Laptop("Dell", 7);
print(lenovo.name, lenovo.count)
print(dell.name, dell.count)
print("Total number of Laptops", Laptop.laptopCount)
Laptop.advantage()
Laptop.resetCount()
print("Total number of Laptops", Laptop.laptopCount)
# Out:
# Lenovo 5
# Dell 7
# Total number of Laptops 12
# Laptops are portable
# Total number of Laptops 0

# %%
#Task 7
class Cat:
  Number_of_cats=0
  def __init__(self,color,action):
    self.color=color 
    self.action=action
    Cat.Number_of_cats+=1
    self.number=Cat.Number_of_cats
  def changeColor(self,color):
    self.color=color 
  def printCat(self):
    print(self.color,'cat is',self.action)
  @classmethod
  def no_parameter(cls):
    info=cls('White','sitting')
    return info
  @classmethod
  def first_parameter(cls,color):
    info=cls(color,'sitting')
    return info
  @classmethod
  def second_parameter(cls,action):
    info=cls('Grey',action)
    return info
print("Total number of cats:", Cat.Number_of_cats) 
c1 = Cat.no_parameter() 
c2 = Cat.first_parameter("Black") 
c3 = Cat("Brown", "jumping") 
c4 = Cat("Red", "purring") 
c5 = Cat.second_parameter("playing")
print("=======================") 
c1.printCat() 
c2.printCat() 
c3.printCat() 
c4.printCat() 
c5.printCat() 
c1.changeColor("Blue") 
c3.changeColor("Purple") 
c1.printCat() 
c3.printCat()
print("=======================")
print("Total number of cats:", Cat.Number_of_cats)
# Out:
# Total number of cats: 0
# ...
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Grey cat is playing
# Blue cat is sitting
# Purple cat is jumping
# ...
# Total number of cats: 5

# %%
#Task 8
import math
class Cylinder:
  radius=5
  height=18
  def __init__(self,radius,height):
      self.radius=radius
      self.height=height
      print(f"Default radius={Cylinder.radius} and height={Cylinder.height}.\nUpdated: radius={radius} and height={height}.")
      Cylinder.radius=radius
      Cylinder.height=height
  @classmethod
  def swap(cls,height,radius):
    info=cls(radius,height)
    return info
  @classmethod
  def changeFormat(cls,data):
    radius,height=data.split('-')
    info=cls(float(radius),float(height))
    return info
  @staticmethod
  def area(radius,height):
    area=2*math.pi*radius*radius+(2*math.pi*radius*height)
    print('Area:',area)
  @staticmethod
  def volume(radius,height):
    volume=math.pi*height*radius*radius
    print('Volume:',volume)
c1 = Cylinder(0,0)
Cylinder.area(c1.radius,c1.height)
Cylinder.volume(c1.radius,c1.height)
print("===============================")
c2 = Cylinder.swap(8,3)
c2.area(c2.radius,c2.height)
c2.volume(c2.radius,c2.height)
print("===============================")
c3 = Cylinder.changeFormat("7-13")
c3.area(c3.radius,c3.height)
c3.volume(c3.radius,c3.height)
print("===============================")
Cylinder(0.3,5.56).area(Cylinder.radius,Cylinder.height)
print("===============================")
Cylinder(3,5).volume(Cylinder.radius,Cylinder.height)
# Out:
# Default radius=5 and height=18.
# Updated: radius=0 and height=0.
# Area: 0.0
# Volume: 0.0
# ...
# Default radius=0 and height=0.
# Updated: radius=3 and height=8.
# Area: 207.34511513692635
# Volume: 226.1946710584651
# ...
# Default radius=3 and height=8.
# Updated: radius=7.0 and height=13.0.
# Area: 879.645943005142
# Volume: 2001.1945203366986
# ...
# Default radius=7.0 and height=13.0.
# Updated: radius=0.3 and height=5.56.
# Area: 11.045839770021713
# ...
# Default radius=0.3 and height=5.56.
# Updated: radius=3 and height=5.
# Volume: 141.37166941154067

# %%
#Task 9
class Student:
    total=0
    brac_stud=0
    other_stud=0    
    @classmethod
    def printDetails(cls):
        print("Total Student(s):",Student.total)
        print('BRAC University Student(s):',Student.brac_stud)
        print('Other Instituion Student(s):',Student.other_stud)        
    def __init__(self,name,department,institute=None):
        Student.total+=1
        self.student_name=name
        self.student_department=department
        if institute==None:
            self.student_institute="BRAC University"
            Student.brac_stud+=1            
        else:
            self.student_institute=institute
            Student.other_stud+=1            
    def individualDetail(self):
        print("Name:",self.student_name)
        print('Department:',self.student_department)
        print("Institution:",self.student_institute)        
    @classmethod
    def createStudent(cls,new_name,new_department,new_institute=None):
        return cls (new_name,new_department,new_institute)    
Student.printDetails() 
print('#########################') 
mikasa = Student('Mikasa Ackerman', "CSE") 
mikasa.individualDetail() 
print('------------------------------------------') 
Student.printDetails() 
print('========================') 
harry = Student.createStudent('Harry Potter', "Defence Against Dark  Arts", "Hogwarts School") 
harry.individualDetail() 
print('-------------------------------------------') 
Student.printDetails() 
print('=========================') 
levi = Student.createStudent("Levi Ackerman", "CSE")
levi.individualDetail() 
print('--------------------------------------------') 
Student.printDetails()
# Out:
# Total Student(s): 0
# BRAC University Student(s): 0
# Other Instituion Student(s): 0
# #########################
# Name: Mikasa Ackerman
# Department: CSE
# Institution: BRAC University
# ------------------------------------------
# Total Student(s): 1
# BRAC University Student(s): 1
# Other Instituion Student(s): 0
# ...
# Name: Harry Potter
# Department: Defence Against Dark  Arts
# Institution: Hogwarts School
# -------------------------------------------
# Total Student(s): 2
# BRAC University Student(s): 1
# Other Instituion Student(s): 1
# ...
# Name: Levi Ackerman
# Department: CSE
# Institution: BRAC University
# --------------------------------------------
# Total Student(s): 3
# BRAC University Student(s): 2
# Other Instituion Student(s): 1

# %%
#Task 10
class SultansDine:
    branches = 0
    sells = 0
    List= []
    def __init__(self,place):
        self.place = place
        SultansDine.branches+=1
        SultansDine.List.append(place)        
    def sellQuantity(self,amount):
        if amount <10:
            self.amount  = amount *300
        elif amount < 20:
            self.amount = amount *350
        else:
            self.amount = amount *400        
        self.branch_sells = self.amount
        SultansDine.List.append(self.branch_sells)
        SultansDine.sells +=self.branch_sells
        self.sell_per = (self.branch_sells/SultansDine.sells)*100
        
    def branchInformation(self):
        print('Branch Name:',self.place)
        print('Branch Sell:',self.branch_sells, 'Taka')
    @classmethod
    def details(cls):
        print('Total Number of branch(s):', SultansDine.branches)
        print('Total Sell:',SultansDine.sells,'Taka')
        a = len(SultansDine.List)
        
        for i in range(0,a,2):
            sell_per = (SultansDine.List[i+1]/SultansDine.sells)*100
            new_sell_per = str(round(sell_per, 2))
            
            print('Branch Name:', SultansDine.List[i], 'Branch Sell:',SultansDine.List[i+1],'Taka')
            print("Branch consists of total sell's:", new_sell_per,'%')
SultansDine.details()
print('########################')
dhanmodi = SultansDine('Dhanmondi')
dhanmodi.sellQuantity(25)
dhanmodi.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
baily_road = SultansDine('Baily Road')
baily_road.sellQuantity(15)
baily_road.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
gulshan = SultansDine('Gulshan')
gulshan.sellQuantity(9)
gulshan.branchInformation()
print('-----------------------------------------')
SultansDine.details()
# Out:
# Total Number of branch(s): 0
# Total Sell: 0 Taka
# ########################
# Branch Name: Dhanmondi
# Branch Sell: 10000 Taka
# -----------------------------------------
# Total Number of branch(s): 1
# Total Sell: 10000 Taka
# Branch Name: Dhanmondi Branch Sell: 10000 Taka
# Branch consists of total sell's: 100.0 %
# ...
# Branch Name: Baily Road
# Branch Sell: 5250 Taka
# -----------------------------------------
# Total Number of branch(s): 2
# Total Sell: 15250 Taka
# Branch Name: Dhanmondi Branch Sell: 10000 Taka
# Branch consists of total sell's: 65.57 %
# Branch Name: Baily Road Branch Sell: 5250 Taka
# Branch consists of total sell's: 34.43 %
# ...
# Branch Name: Gulshan
# Branch Sell: 2700 Taka
# -----------------------------------------
# Total Number of branch(s): 3
# Total Sell: 17950 Taka
# Branch Name: Dhanmondi Branch Sell: 10000 Taka
# Branch consists of total sell's: 55.71 %
# Branch Name: Baily Road Branch Sell: 5250 Taka
# Branch consists of total sell's: 29.25 %
# ...
